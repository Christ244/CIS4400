# %%
import requests
import yfinance as yf

import matplotlib.pyplot as plt
import pandas as pd

# %%
# get company stock ticker

def getTicker(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

# %%
company_names = ["JPMorgan Chase & Co.", 
                 "Bank of America Corporation", 
                 "Citigroup Inc.",
                 "Wells Fargo & Company",
                 "The Toronto-Dominion Bank",
                 "UBS Group AG",
                 "Credit Suisse",
                 "BMO",
                 "NatWest Group plc",
                 "U.S. Bancorp",
                 "Truist Financial Corporation",
                 "The PNC Financial Services Group, Inc.",
                 "SVB",
                 "Signature Bank",
                 "First Republic Bank",
                 "M&T Bank Corporation",
                 "HDFC Bank Limited",
                 "Citizens Financial Group, Inc.",
                 "New York Community Bancorp",
                 "PacWest Bancorp"]

# %%
Symbol = [getTicker(name) for name in company_names]
company_name_symbol = pd.DataFrame({"Company_name": company_names,
                                     "Symbol":Symbol})

# %%
# company_name_symbol.to_csv("company_name_symbol.csv", sep='\t', encoding='utf-8')

# %%
Symbol
# Out:
# ['JPM',
#  'BAC',
#  'C',
#  'WFC',
#  'TD.TO',
#  'UBS',
#  'USOI',
#  'BMO',
#  'NWG',
#  'USB',
#  'TFC',
#  'PNC',
#  'SIVBQ',
#  'SBNY',
#  'FRCB',
#  'MTB',
#  'HDB',
#  'CFG',
#  'NYCB',
#  'PACW']

# %%
# Get the data for the stocklist
data = yf.download(Symbol,'2019-09-01','2020-12-31')
# Out:
# [*********************100%***********************]  20 of 20 completed

# %%
# Plot the close price of the stock
fig = plt.figure(figsize=(18, 15))
ax = plt.axes()
ax.plot(data['Adj Close'])
ax.set(
       xlabel='Date', ylabel='Stock Price of Adjusted Close ',
       title='Stock Price History of  ' + '20 Stocks');
plt.legend(stockList, loc='upper left')

# %%
userInput = Symbol[0]
# Get the data for the stocklist
user_data0 = yf.download(userInput,'2019-09-01','2020-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Plot the close price of the stock
fig = plt.figure(figsize=(18, 15))
ax = plt.axes()

ax.plot(user_data0['Adj Close'])

ax.set(xlabel='Date', ylabel='Stock Price of Adjusted Close ',
       title='Stock Price History of  ' + userInput);

# %% [markdown]
# <h1>The purpose of the following code is to down load the stock price of all companies automatically<h1>

# %% [markdown]
# <span style="color:red">
# - Method one. use the data with 20 companies
# </span>

# %%
# the data down loaded with the list of company symbols
data
# Out:
#             Adj Close                                                          \
#                   BAC        BMO          C        CFG        FRCB        HDB
# Date
# 2019-09-03  24.599079  57.662560  55.306328  27.826580   86.101555  51.191494
# 2019-09-04  24.999214  57.985844  56.056290  28.131155   86.629555  51.352367
# 2019-09-05  25.740677  58.947178  57.852749  28.934904   87.675766  50.489506
# 2019-09-06  25.383677  59.474617  57.530083  28.884144   87.206451  50.850250
# 2019-09-09  26.207527  60.291325  59.989319  30.220901   89.073952  50.860001
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-23  28.399290  68.559486  55.537094  32.005119  138.538696  67.342094
# 2020-12-24  28.314236  68.731537  55.345215  31.787889  138.607712  67.810081
# 2020-12-28  28.474901  68.740601  55.856911  31.778847  140.718460  68.833817
# 2020-12-29  28.361490  68.668159  55.655880  31.570667  140.452148  68.950813
# ...

# %%
# user_data0 is the stok price data down load base on the first symbol in the symbolList
list(user_data0)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
Symbol[0]
# Out:
# 'JPM'

# %%
data[list(user_data0)[0]].iloc[:,0]
# Out:
# Date
# 2019-09-03    27.209999
# 2019-09-04    27.320000
# 2019-09-05    27.850000
# 2019-09-06    28.020000
# 2019-09-09    28.000000
#                 ...
# 2020-12-23    29.389999
# 2020-12-24    30.270000
# 2020-12-28    30.230000
# 2020-12-29    30.170000
# 2020-12-30    30.000000
# Name: BAC, Length: 341, dtype: float64

# %%
"""
when I test them independently, they worked fine, but once I put them in a for loop, there's a problem
"""

df = pd.DataFrame()
for i in list(len(Symbol)):
    for j in list(len(user_data0)):
        df = pd.concat([data[list(user_data0)[j]].iloc[:,i], data[list(user_data0)[j]].iloc[:,i+20]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17440/2269120574.py in <module>
#       4
#       5 df = pd.DataFrame()
# ----> 6 for i in list(len(Symbol)):
#       7     for j in list(len(user_data0)):
#       8         df = pd.concat([data[list(user_data0)[j]].iloc[:,i], data[list(user_data0)[j]].iloc[:,i+20]], axis=1)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# <span style="color:red">
# - Method two. concat individual company data
# </span>

# %%
"""
Can I use a for loop here to get stock price of all companies?
"""

df = pd.DataFrame
for s in Symbol: 
    df = pd.concat([df,yf.download(s,'2019-09-01','2020-12-31')], ignore_index=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17440/4232443020.py in <module>
#       5 df = pd.DataFrame
#       6 for s in Symbol:
# ----> 7     df = pd.concat([df,yf.download(s,'2019-09-01','2020-12-31')], ignore_index=True)
#       8
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
# ...
