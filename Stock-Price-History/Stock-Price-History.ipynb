# %%
import requests
import yfinance as yf

import matplotlib.pyplot as plt
import pandas as pd

# %%
# get company stock ticker

def getTicker(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

# %%
company_names = ["JPMorgan Chase & Co.", 
                 "Bank of America Corporation", 
                 "Citigroup Inc.",
                 "Wells Fargo & Company",
                 "The Toronto-Dominion Bank",
                 "UBS Group AG",
                 "Credit Suisse",
                 "BMO",
                 "NatWest Group plc",
                 "U.S. Bancorp",
                 "Truist Financial Corporation",
                 "The PNC Financial Services Group, Inc.",
                 "SVB",
                 "Signature Bank",
                 "First Republic Bank",
                 "M&T Bank Corporation",
                 "HDFC Bank Limited",
                 "Citizens Financial Group, Inc.",
                 "New York Community Bancorp",
                 "PacWest Bancorp"]

# %%
Symbol = [getTicker(name) for name in company_names]
company_name_symbol = pd.DataFrame({"Company_name": company_names,
                                     "Symbol":Symbol})

# %%
#company_name_symbol.to_csv("./data/company_name_symbol.csv")

# %%
Symbol
# Out:
# ['JPM',
#  'BAC',
#  'C',
#  'WFC',
#  'TD.TO',
#  'UBS',
#  'USOI',
#  'BMO',
#  'NWG',
#  'USB',
#  'TFC',
#  'PNC',
#  'SIVBQ',
#  'SBNY',
#  'FRCB',
#  'MTB',
#  'HDB',
#  'CFG',
#  'NYCB',
#  'PACW']

# %%
# Get the data for the stocklist
data = yf.download(Symbol,'2019-09-01','2020-12-31')
# Out:
# [*********************100%***********************]  20 of 20 completed

# %%
# Plot the close price of the stock
fig = plt.figure(figsize=(18, 15))
ax = plt.axes()
ax.plot(data['Adj Close'])
ax.set(
       xlabel='Date', ylabel='Stock Price of Adjusted Close ',
       title='Stock Price History of  ' + '20 Stocks');
plt.legend(stockList, loc='upper left')

# %%
for s in Symbol:
    # get stock price history
    user_data = yf.download(s ,'2019-09-01','2020-12-31') 
    # save stock price in data folder
    user_data.to_csv('./data/' + s +".csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
userInput = Symbol[0]
# read data base on user input
user_data = pd.read_csv('./data/' + userInput +".csv")

# %%
# Plot the close price of the stock
fig = plt.figure(figsize=(18, 15))
ax = plt.axes()

ax.plot(user_data['Adj Close'])

ax.set(xlabel='Date', ylabel='Stock Price of Adjusted Close ',
       title='Stock Price History of  ' + userInput);
